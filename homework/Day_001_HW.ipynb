# %% [markdown]
# 作業1
# 1.      你選的這組資料為何重要?
# 台灣也位於環太平洋地震帶，地震對台灣來說已經是家常便飯，精準的地震預測能有效降低災害規模。
# 2.      資料從何而來? (tips: 譬如提供者是誰、以什麼方式蒐集)
# 地球物理學組:B. Rouet-Leduc為比賽準備了數據，地球科學系: 數據來自Chas Bolton，Jacques Riviere，Paul Johnson和Chris Marone教授的實驗。
# 3.      蒐集而來的資料型態為何?
# acoustic_data - 地震信號[int16]
# time_to_failure  - 直到下一次實驗室地震的時間（以秒為單位）[float64]
# seg_id - 應對其進行預測的測試段ID（每個段一個預測）
# 4.      這組資料想解決的問題如何評估?
# 預測地震，評估方式，Submissions are evaluated using the mean absolute error between the predicted time remaining before the next lab earthquake and the act remaining time.
#
# 作業2
# 1.   核心問題為何?
# 為了提升業績，我認為透過OBD裝置將車況等資訊即時傳回後台，可結合導航讓司機把握路況，快速安全的將乘客送至目的地。
# 2.      資料從何而來?
# OBD裝置收集車的所有儀表板資料，包括車速、油耗等等
# 3.      蒐集而來的資料型態為何?
# 車速:Float(浮點數)
# 油量:Float
# 4.   你要回答的問題，其如何評估 (tips：你的假設如何驗證)?
# OBD回傳每次載客時間、車平均車速、油耗等，然後根據當時路況路線判斷。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=MSE=sum((y-yp)**2)/len(y)
    return mse
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 173.169

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 173.169
# The Mean absolute error is 9.923

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
